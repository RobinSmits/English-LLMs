# %%
# Import Modules
from datasets import load_dataset
from huggingface_hub import notebook_login
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model, TaskType
from transformers import AutoConfig, AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, DataCollatorForLanguageModeling, Trainer, TrainingArguments
import torch

# %%
# Set Name Constants
model_name = 'mistralai/Mistral-7B-Instruct-v0.2'
hf_model_name = 'Mistral-Instruct-7B-v0.2-ChatAlpaca'

# %%
# HuggingFace Hub Login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Create Model with QLoRa

# %%
# Create Config
config = AutoConfig.from_pretrained(model_name, use_cache = False)

# Create Model
model = AutoModelForCausalLM.from_pretrained(model_name,
                                             config = config,
                                             attn_implementation = 'flash_attention_2', 
                                             torch_dtype = torch.bfloat16,
                                             device_map = {"":0},
                                             quantization_config = BitsAndBytesConfig(load_in_4bit = True,
                                                                                      bnb_4bit_use_double_quant = True,
                                                                                      bnb_4bit_quant_type = 'nf4',
                                                                                      bnb_4bit_compute_dtype = torch.bfloat16))

# Create LoRA config
loraconfig = LoraConfig(r = 32,
                        lora_alpha = 16,
                        target_modules = ['q_proj', 'v_proj'],
                        lora_dropout = 0.05,
                        bias = 'none',
                        task_type = TaskType.CAUSAL_LM)

# Prepare for Training
model = prepare_model_for_kbit_training(model)

# Create LoRA Model
model = get_peft_model(model, loraconfig)
model.print_trainable_parameters()

# Show Model Summary
print(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# trainable params: 13,631,488 || all params: 7,255,363,584 || trainable%: 0.18788152850204565
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralFlashAttention2(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Dataset and Tokenization

# %%
# Create Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Max Length
MAX_LEN = 2048

# Tokenizer Summary
print(tokenizer)
# Out:
# LlamaTokenizerFast(name_or_path='mistralai/Mistral-7B-Instruct-v0.2', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '</s>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
# Load ChatAlpaca
datasets = load_dataset('robinsmits/ChatAlpaca-20K')

# Train and Val datasets
train_data = datasets['train']
test_data = datasets['test']

# Summary
print(train_data)
print(test_data)
# Out:
# Dataset({
#     features: ['id', 'messages'],
#     num_rows: 19600
# })
# Dataset({
#     features: ['id', 'messages'],
#     num_rows: 400
# })

# %%
# Show some samples
counter = 0
for item_data in train_data:
    print('\n=======================================================================')
    chat_template_string = tokenizer.apply_chat_template(item_data["messages"], tokenize = False)
    print(chat_template_string)

    counter += 1
    if counter == 2:
        break
# Out:
# =======================================================================
# <s>[INST] Find the product of the numbers: 5 and 8 [/INST]The product of 5 and 8 is 40.</s>[INST] What is the sum of the numbers 6 and 12? [/INST]The sum of the numbers 6 and 12 is 18.</s>[INST] Can you tell me the quotient of 20 and 5? [/INST]Yes, the quotient of 20 and 5 is 4.</s>[INST] What is the difference between 25 and 13? [/INST]The difference between 25 and 13 is 12.</s>[INST] What is the square of 9? [/INST]The square of 9 is 81.</s>[INST] What is the cube of 6? [/INST]The cube of 6 is 216.</s>
#
# =======================================================================
# <s>[INST] Provide five tips for effectively using tape measures [/INST]1. Tighten the tape measure so that it stays in place when measuring.
# 2. Make sure that the hook of the tape measure hits the starting point precisely.
# 3. Allow for a bit of slack when measuring around curves or corners.
# 4. Measure from a stable surface, such as a table or workbench.
# 5. Mark the beginning and end of each measurement with a pen or marker.</s>[INST] Can you give me an example of when to use tip number three, "Allow for a bit of slack when measuring around curves or corners"? [/INST]Sure! Let's say you're measuring the circumference of a circular object, like a pipe. If you pull the tape measure too tightly, you won't get an accurate measurement because the tape measure will be stretched out of its original shape, making the measurement longer than it should be. Instead, you should wrap the tape measure around the curve or corner of the object without pulling it too tightly. This way, you'll get a more accurate measurement that takes into account the shape of the object.</s>[INST] Can you tell me more about the markers or pens that should be used to mark the measurements? Do you recommend a certain type of pen? [/INST]As an AI language model, I do not have personal preferences as a human, but there are certain types of markers or pens that are better suited for marking measurements than others. For example, a fine-tipped marker or mechanical pencil is great for making precise marks on a tape measure, because they produce a precise line that is easy to see. You'll want to avoid using a ballpoint pen or a marker with a thick tip, since these types of pens can produce marks that are too thick or blurry, making it difficult to accurately read the measurement. It's also a good idea to choose a marker or pen that is a different color than the color of the tape measure, so that you can easily distinguish your marks from the printed markings on the tape measure.</s>[INST] Are there any other tips you recommend for maintaining tape measures in good condition?  [/INST]Yes, there are several tips you can use to maintain your tape measures in good condition:
#
# 1. Clean your tape measure regularly: Use a soft cloth or a damp sponge to clean the surface of the tape measure. Avoid using harsh chemicals or abrasives that could damage the markings on the tape measure.
#
# 2. Store your tape measure properly: Keep your tape measure in a dry place, away from moisture and direct sunlight. Avoid storing your tape measure in a place where it could get crushed or bent, as this could damage the internal components.
#
# 3. Wind the tape measure properly: When you're done using your tape measure, wind the tape back into the housing carefully to avoid twisting or kinking the tape. Make sure the hook is fully retracted and secure the lock.
#
# 4. Lubricate the mechanism: Use a light lubricant like silicone spray to keep the internal components of the tape measure moving smoothly. Be careful not to over-lubricate, as this could cause the tape measure to become greasy and difficult to handle.
#
# By following these tips, you can help to ensure that your tape measures are always in good working condition, and that you'll be able to rely on them for accurate measurements every time you use them.</s>

# %%
train_data = train_data.shuffle().map(lambda x: {"input_ids": tokenizer.apply_chat_template(x['messages'], 
                                                                                            tokenize = True, 
                                                                                            max_length = MAX_LEN,
                                                                                            truncation = True,
                                                                                            add_generation_prompt = False)})

test_data = test_data.map(lambda x: {"input_ids": tokenizer.apply_chat_template(x['messages'], 
                                                                                tokenize = True,
                                                                                max_length = MAX_LEN,
                                                                                truncation = True,
                                                                                add_generation_prompt = False)})
# Out:
# Map:   0%|          | 0/19600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]

# %% [markdown]
# ## Train Model

# %%
# Set Steps
eval_steps = 120
save_steps = 120
logging_steps = 60

# Config Trainer
trainer = Trainer(model = model,
                  train_dataset = train_data,
                  eval_dataset = test_data,
                  args = TrainingArguments(num_train_epochs = 2,
                                            learning_rate = 4.0e-5,
                                            lr_scheduler_type = 'cosine',
                                            evaluation_strategy = "steps",
                                            logging_steps = logging_steps,
                                            save_strategy = 'steps',
                                            eval_steps = eval_steps,
                                            save_steps = save_steps,
                                            save_total_limit = 1,
                                            per_device_train_batch_size = 1,
                                            per_device_eval_batch_size = 2,
                                            gradient_accumulation_steps = 32,
                                            gradient_checkpointing = True, 
                                            gradient_checkpointing_kwargs = {'use_reentrant': False},
                                            warmup_ratio = 0.05,
                                            bf16 = True,
                                            output_dir = hf_model_name,
                                            hub_model_id = hf_model_name,
                                            push_to_hub = True,
                                            hub_private_repo = True,
                                            optim = 'paged_adamw_8bit',
                                            report_to = 'tensorboard'),
                  data_collator = DataCollatorForLanguageModeling(tokenizer, mlm = False))

# Perform Training
trainer.train()
# Out:
#   0%|          | 0/1224 [00:00<?, ?it/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
# {'loss': 1.7126, 'learning_rate': 3.870967741935484e-05, 'epoch': 0.1}
# {'loss': 0.99, 'learning_rate': 3.975461196492672e-05, 'epoch': 0.2}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.9355368614196777, 'eval_runtime': 278.7532, 'eval_samples_per_second': 1.435, 'eval_steps_per_second': 0.717, 'epoch': 0.2}
# {'loss': 0.9117, 'learning_rate': 3.899082861757382e-05, 'epoch': 0.29}
# {'loss': 0.8793, 'learning_rate': 3.7728411884165516e-05, 'epoch': 0.39}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8847938776016235, 'eval_runtime': 278.6092, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 0.39}
# {'loss': 0.8666, 'learning_rate': 3.600050845582669e-05, 'epoch': 0.49}
# {'loss': 0.8671, 'learning_rate': 3.3852487092109635e-05, 'epoch': 0.59}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8736782073974609, 'eval_runtime': 278.6063, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 0.59}
# {'loss': 0.8635, 'learning_rate': 3.134074739449979e-05, 'epoch': 0.69}
# {'loss': 0.8662, 'learning_rate': 2.8531238948216945e-05, 'epoch': 0.78}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.867875337600708, 'eval_runtime': 278.6174, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 0.78}
# {'loss': 0.8609, 'learning_rate': 2.5497729714519234e-05, 'epoch': 0.88}
# {'loss': 0.8627, 'learning_rate': 2.231986913953085e-05, 'epoch': 0.98}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8639066815376282, 'eval_runtime': 278.6727, 'eval_samples_per_second': 1.435, 'eval_steps_per_second': 0.718, 'epoch': 0.98}
# {'loss': 0.8632, 'learning_rate': 1.908109683564722e-05, 'epoch': 1.08}
# {'loss': 0.8426, 'learning_rate': 1.586645174630094e-05, 'epoch': 1.18}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8615077137947083, 'eval_runtime': 278.6343, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 1.18}
# {'loss': 0.8441, 'learning_rate': 1.2760339317833822e-05, 'epoch': 1.27}
# {'loss': 0.8574, 'learning_rate': 9.84431530480847e-06, 'epoch': 1.37}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8597739934921265, 'eval_runtime': 278.5966, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 1.37}
# {'loss': 0.8505, 'learning_rate': 7.194944398356267e-06, 'epoch': 1.47}
# {'loss': 0.8473, 'learning_rate': 4.88178990256488e-06, 'epoch': 1.57}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8589327931404114, 'eval_runtime': 278.6621, 'eval_samples_per_second': 1.435, 'eval_steps_per_second': 0.718, 'epoch': 1.57}
# {'loss': 0.8456, 'learning_rate': 2.965587243040666e-06, 'epoch': 1.67}
# {'loss': 0.8528, 'learning_rate': 1.4966492649852683e-06, 'epoch': 1.76}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8585439324378967, 'eval_runtime': 278.6346, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 1.76}
# {'loss': 0.8452, 'learning_rate': 5.135451921357337e-07, 'epoch': 1.86}
# {'loss': 0.852, 'learning_rate': 4.208793253106303e-08, 'epoch': 1.96}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'eval_loss': 0.8584455847740173, 'eval_runtime': 278.5594, 'eval_samples_per_second': 1.436, 'eval_steps_per_second': 0.718, 'epoch': 1.96}
# {'train_runtime': 81006.6231, 'train_samples_per_second': 0.484, 'train_steps_per_second': 0.015, 'train_loss': 0.9080663210426281, 'epoch': 2.0}
# TrainOutput(global_step=1224, training_loss=0.9080663210426281, metrics={'train_runtime': 81006.6231, 'train_samples_per_second': 0.484, 'train_steps_per_second': 0.015, 'train_loss': 0.9080663210426281, 'epoch': 2.0})

# %% [markdown]
# ## Push to Hub

# %%
# Push model to hub
trainer.push_to_hub()

# Push tokenizer to hub
tokenizer.push_to_hub(hf_model_name, private = True)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# events.out.tfevents.1705174943.DS10.7408.0:   0%|          | 0.00/11.0k [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/54.5M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/robinsmits/Mistral-Instruct-7B-v0.2-ChatAlpaca/commit/535b3535d47d2bb98779d2dd2a8e8d96726291f1', commit_message='Upload tokenizer', commit_description='', oid='535b3535d47d2bb98779d2dd2a8e8d96726291f1', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Base Model Evaluation

# %%
# !lm_eval --model hf \
         --model_args pretrained=mistralai/Mistral-7B-Instruct-v0.2 \
         --tasks mmlu,hellaswag,winogrande,piqa,arc_easy,arc_challenge,mathqa,openbookqa \
         --device cuda \
         --batch_size 1 \
         --verbosity ERROR
# Out:
# 2024-01-16:14:17:30,538 INFO     [utils.py:148] Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-01-16:14:17:30,538 INFO     [utils.py:160] NumExpr defaulting to 8 threads.
# 2024-01-16:14:17:30,653 INFO     [config.py:58] PyTorch version 2.1.2 available.
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:00<00:00, 12.99it/s]
# /home/robin/environments/LLM/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading data: 100%|████████████████████| 9.01M/9.01M [00:03<00:00, 2.61MB/s]
# Downloading data: 100%|██████████████████████| 903k/903k [00:00<00:00, 1.29MB/s]
# Downloading data: 100%|█████████████████████| 1.35M/1.35M [00:02<00:00, 526kB/s]
# Generating train split: 100%|██| 29837/29837 [00:00<00:00, 617620.97 examples/s]
# Generating test split: 100%|█████| 2985/2985 [00:00<00:00, 854257.47 examples/s]
# Generating validation split: 100%|█| 4475/4475 [00:00<00:00, 1227487.44 examples
# /home/robin/environments/LLM/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading readme: 100%|██████████████████| 9.06k/9.06k [00:00<00:00, 4.50MB/s]
# Downloading data: 100%|███████████████████████| 496k/496k [00:00<00:00, 662kB/s]
# Downloading data: 100%|█████████████████████| 58.2k/58.2k [00:00<00:00, 179kB/s]
# Downloading data: 100%|█████████████████████| 55.5k/55.5k [00:00<00:00, 179kB/s]
# Generating train split: 100%|████| 4957/4957 [00:00<00:00, 321252.88 examples/s]
# Generating validation split: 100%|█| 500/500 [00:00<00:00, 105538.32 examples/s]
# Generating test split: 100%|████████| 500/500 [00:00<00:00, 69649.68 examples/s]
# Downloading data: 100%|████████████████████| 2.66M/2.66M [00:01<00:00, 2.27MB/s]
# Downloading data: 100%|██████████████████████| 502k/502k [00:00<00:00, 1.06MB/s]
# Downloading data: 100%|███████████████████████| 301k/301k [00:00<00:00, 720kB/s]
# Generating train split: 16113 examples [00:00, 736372.77 examples/s]
# Generating test split: 3084 examples [00:00, 493805.44 examples/s]
# Generating validation split: 1838 examples [00:00, 494333.49 examples/s]
# 100%|█████████████████████████████████| 133659/133659 [2:42:44<00:00, 13.69it/s]
# hf (pretrained=mistralai/Mistral-7B-Instruct-v0.2), gen_kwargs: (), limit: None, num_fewshot: None, batch_size: 1
# |                 Tasks                 |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------------------------------------|-------|------|-----:|--------|-----:|---|-----:|
# |arc_challenge                          |Yaml   |none  |     0|acc     |0.5418|±  |0.0146|
# |                                       |       |none  |     0|acc_norm|0.5589|±  |0.0145|
# |arc_easy                               |Yaml   |none  |     0|acc     |0.8131|±  |0.0080|
# |                                       |       |none  |     0|acc_norm|0.7668|±  |0.0087|
# |hellaswag                              |Yaml   |none  |     0|acc     |0.6605|±  |0.0047|
# |                                       |       |none  |     0|acc_norm|0.8368|±  |0.0037|
# |mathqa                                 |Yaml   |none  |     0|acc     |0.3672|±  |0.0088|
# |                                       |       |none  |     0|acc_norm|0.3688|±  |0.0088|
# |mmlu                                   |N/A    |none  |     0|acc     |0.5900|±  |0.1349|
# | - humanities                          |N/A    |none  |     0|acc     |0.5382|±  |0.1550|
# |  - formal_logic                       |Yaml   |none  |     0|acc     |0.3571|±  |0.0429|
# |  - high_school_european_history       |Yaml   |none  |     0|acc     |0.7273|±  |0.0348|
# |  - high_school_us_history             |Yaml   |none  |     0|acc     |0.7794|±  |0.0291|
# |  - high_school_world_history          |Yaml   |none  |     0|acc     |0.7806|±  |0.0269|
# |  - international_law                  |Yaml   |none  |     0|acc     |0.7603|±  |0.0390|
# |  - jurisprudence                      |Yaml   |none  |     0|acc     |0.7222|±  |0.0433|
# |  - logical_fallacies                  |Yaml   |none  |     0|acc     |0.7607|±  |0.0335|
# |  - moral_disputes                     |Yaml   |none  |     0|acc     |0.6532|±  |0.0256|
# |  - moral_scenarios                    |Yaml   |none  |     0|acc     |0.3385|±  |0.0158|
# |  - philosophy                         |Yaml   |none  |     0|acc     |0.6495|±  |0.0271|
# |  - prehistory                         |Yaml   |none  |     0|acc     |0.6728|±  |0.0261|
# |  - professional_law                   |Yaml   |none  |     0|acc     |0.4172|±  |0.0126|
# |  - world_religions                    |Yaml   |none  |     0|acc     |0.8187|±  |0.0295|
# | - other                               |N/A    |none  |     0|acc     |0.6640|±  |0.1151|
# |  - business_ethics                    |Yaml   |none  |     0|acc     |0.5900|±  |0.0494|
# |  - clinical_knowledge                 |Yaml   |none  |     0|acc     |0.6679|±  |0.0290|
# |  - college_medicine                   |Yaml   |none  |     0|acc     |0.5665|±  |0.0378|
# |  - global_facts                       |Yaml   |none  |     0|acc     |0.4000|±  |0.0492|
# |  - human_aging                        |Yaml   |none  |     0|acc     |0.6278|±  |0.0324|
# |  - management                         |Yaml   |none  |     0|acc     |0.7379|±  |0.0435|
# |  - marketing                          |Yaml   |none  |     0|acc     |0.8675|±  |0.0222|
# |  - medical_genetics                   |Yaml   |none  |     0|acc     |0.6300|±  |0.0485|
# |  - miscellaneous                      |Yaml   |none  |     0|acc     |0.7905|±  |0.0146|
# |  - nutrition                          |Yaml   |none  |     0|acc     |0.6667|±  |0.0270|
# |  - professional_accounting            |Yaml   |none  |     0|acc     |0.4539|±  |0.0297|
# |  - professional_medicine              |Yaml   |none  |     0|acc     |0.6654|±  |0.0287|
# |  - virology                           |Yaml   |none  |     0|acc     |0.4518|±  |0.0387|
# | - social_sciences                     |N/A    |none  |     0|acc     |0.6874|±  |0.0862|
# |  - econometrics                       |Yaml   |none  |     0|acc     |0.4825|±  |0.0470|
# |  - high_school_geography              |Yaml   |none  |     0|acc     |0.7525|±  |0.0307|
# |  - high_school_government_and_politics|Yaml   |none  |     0|acc     |0.8135|±  |0.0281|
# |  - high_school_macroeconomics         |Yaml   |none  |     0|acc     |0.5744|±  |0.0251|
# |  - high_school_microeconomics         |Yaml   |none  |     0|acc     |0.6429|±  |0.0311|
# |  - high_school_psychology             |Yaml   |none  |     0|acc     |0.7908|±  |0.0174|
# |  - human_sexuality                    |Yaml   |none  |     0|acc     |0.6870|±  |0.0407|
# |  - professional_psychology            |Yaml   |none  |     0|acc     |0.5866|±  |0.0199|
# |  - public_relations                   |Yaml   |none  |     0|acc     |0.6636|±  |0.0453|
# |  - security_studies                   |Yaml   |none  |     0|acc     |0.7061|±  |0.0292|
# |  - sociology                          |Yaml   |none  |     0|acc     |0.8408|±  |0.0259|
# |  - us_foreign_policy                  |Yaml   |none  |     0|acc     |0.8200|±  |0.0386|
# | - stem                                |N/A    |none  |     0|acc     |0.4995|±  |0.1079|
# |  - abstract_algebra                   |Yaml   |none  |     0|acc     |0.3000|±  |0.0461|
# |  - anatomy                            |Yaml   |none  |     0|acc     |0.5852|±  |0.0426|
# |  - astronomy                          |Yaml   |none  |     0|acc     |0.6316|±  |0.0393|
# |  - college_biology                    |Yaml   |none  |     0|acc     |0.6389|±  |0.0402|
# |  - college_chemistry                  |Yaml   |none  |     0|acc     |0.3900|±  |0.0490|
# |  - college_computer_science           |Yaml   |none  |     0|acc     |0.5300|±  |0.0502|
# |  - college_mathematics                |Yaml   |none  |     0|acc     |0.3300|±  |0.0473|
# |  - college_physics                    |Yaml   |none  |     0|acc     |0.3922|±  |0.0486|
# |  - computer_security                  |Yaml   |none  |     0|acc     |0.6700|±  |0.0473|
# |  - conceptual_physics                 |Yaml   |none  |     0|acc     |0.5106|±  |0.0327|
# |  - electrical_engineering             |Yaml   |none  |     0|acc     |0.5586|±  |0.0414|
# |  - elementary_mathematics             |Yaml   |none  |     0|acc     |0.4286|±  |0.0255|
# |  - high_school_biology                |Yaml   |none  |     0|acc     |0.7000|±  |0.0261|
# |  - high_school_chemistry              |Yaml   |none  |     0|acc     |0.5025|±  |0.0352|
# |  - high_school_computer_science       |Yaml   |none  |     0|acc     |0.6100|±  |0.0490|
# |  - high_school_mathematics            |Yaml   |none  |     0|acc     |0.3556|±  |0.0292|
# |  - high_school_physics                |Yaml   |none  |     0|acc     |0.3709|±  |0.0394|
# |  - high_school_statistics             |Yaml   |none  |     0|acc     |0.4583|±  |0.0340|
# |  - machine_learning                   |Yaml   |none  |     0|acc     |0.4643|±  |0.0473|
# |openbookqa                             |Yaml   |none  |     0|acc     |0.3560|±  |0.0214|
# |                                       |       |none  |     0|acc_norm|0.4540|±  |0.0223|
# |piqa                                   |Yaml   |none  |     0|acc     |0.8014|±  |0.0093|
# |                                       |       |none  |     0|acc_norm|0.8041|±  |0.0093|
# |winogrande                             |Yaml   |none  |     0|acc     |0.7388|±  |0.0123|
#
# |      Groups      |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------------------|-------|------|-----:|------|-----:|---|-----:|
# |mmlu              |N/A    |none  |     0|acc   |0.5900|±  |0.1349|
# | - humanities     |N/A    |none  |     0|acc   |0.5382|±  |0.1550|
# | - other          |N/A    |none  |     0|acc   |0.6640|±  |0.1151|
# | - social_sciences|N/A    |none  |     0|acc   |0.6874|±  |0.0862|
# | - stem           |N/A    |none  |     0|acc   |0.4995|±  |0.1079|

# %% [markdown]
# ## Finetuned Model Evaluation

# %%
# !lm_eval --model hf \
         --model_args pretrained=mistralai/Mistral-7B-Instruct-v0.2,peft=robinsmits/Mistral-Instruct-7B-v0.2-ChatAlpaca \
         --tasks mmlu,hellaswag,winogrande,piqa,arc_easy,arc_challenge,mathqa,openbookqa \
         --device cuda \
         --batch_size 1 \
         --verbosity ERROR
# Out:
# 2024-01-16:17:06:08,496 INFO     [utils.py:148] Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-01-16:17:06:08,496 INFO     [utils.py:160] NumExpr defaulting to 8 threads.
# 2024-01-16:17:06:08,607 INFO     [config.py:58] PyTorch version 2.1.2 available.
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:00<00:00, 13.48it/s]
# /home/robin/environments/LLM/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /home/robin/environments/LLM/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 100%|█████████████████████████████████| 133659/133659 [2:44:44<00:00, 13.52it/s]
# hf (pretrained=mistralai/Mistral-7B-Instruct-v0.2,peft=robinsmits/Mistral-Instruct-7B-v0.2-ChatAlpaca), gen_kwargs: (), limit: None, num_fewshot: None, batch_size: 1
# |                 Tasks                 |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------------------------------------|-------|------|-----:|--------|-----:|---|-----:|
# |arc_challenge                          |Yaml   |none  |     0|acc     |0.5290|±  |0.0146|
# |                                       |       |none  |     0|acc_norm|0.5418|±  |0.0146|
# |arc_easy                               |Yaml   |none  |     0|acc     |0.8224|±  |0.0078|
# |                                       |       |none  |     0|acc_norm|0.7837|±  |0.0084|
# |hellaswag                              |Yaml   |none  |     0|acc     |0.6107|±  |0.0049|
# |                                       |       |none  |     0|acc_norm|0.8013|±  |0.0040|
# |mathqa                                 |Yaml   |none  |     0|acc     |0.3755|±  |0.0089|
# |                                       |       |none  |     0|acc_norm|0.3846|±  |0.0089|
# |mmlu                                   |N/A    |none  |     0|acc     |0.5743|±  |0.1427|
# | - humanities                          |N/A    |none  |     0|acc     |0.5158|±  |0.1640|
# |  - formal_logic                       |Yaml   |none  |     0|acc     |0.3730|±  |0.0433|
# |  - high_school_european_history       |Yaml   |none  |     0|acc     |0.6909|±  |0.0361|
# |  - high_school_us_history             |Yaml   |none  |     0|acc     |0.7696|±  |0.0296|
# |  - high_school_world_history          |Yaml   |none  |     0|acc     |0.7637|±  |0.0277|
# |  - international_law                  |Yaml   |none  |     0|acc     |0.7273|±  |0.0407|
# |  - jurisprudence                      |Yaml   |none  |     0|acc     |0.7315|±  |0.0428|
# |  - logical_fallacies                  |Yaml   |none  |     0|acc     |0.7546|±  |0.0338|
# |  - moral_disputes                     |Yaml   |none  |     0|acc     |0.6561|±  |0.0256|
# |  - moral_scenarios                    |Yaml   |none  |     0|acc     |0.2380|±  |0.0142|
# |  - philosophy                         |Yaml   |none  |     0|acc     |0.6270|±  |0.0275|
# |  - prehistory                         |Yaml   |none  |     0|acc     |0.6512|±  |0.0265|
# |  - professional_law                   |Yaml   |none  |     0|acc     |0.4283|±  |0.0126|
# |  - world_religions                    |Yaml   |none  |     0|acc     |0.7895|±  |0.0313|
# | - other                               |N/A    |none  |     0|acc     |0.6585|±  |0.1141|
# |  - business_ethics                    |Yaml   |none  |     0|acc     |0.6000|±  |0.0492|
# |  - clinical_knowledge                 |Yaml   |none  |     0|acc     |0.6642|±  |0.0291|
# |  - college_medicine                   |Yaml   |none  |     0|acc     |0.5549|±  |0.0379|
# |  - global_facts                       |Yaml   |none  |     0|acc     |0.3600|±  |0.0482|
# |  - human_aging                        |Yaml   |none  |     0|acc     |0.6143|±  |0.0327|
# |  - management                         |Yaml   |none  |     0|acc     |0.7184|±  |0.0445|
# |  - marketing                          |Yaml   |none  |     0|acc     |0.8803|±  |0.0213|
# |  - medical_genetics                   |Yaml   |none  |     0|acc     |0.6400|±  |0.0482|
# |  - miscellaneous                      |Yaml   |none  |     0|acc     |0.7778|±  |0.0149|
# |  - nutrition                          |Yaml   |none  |     0|acc     |0.6765|±  |0.0268|
# |  - professional_accounting            |Yaml   |none  |     0|acc     |0.4539|±  |0.0297|
# |  - professional_medicine              |Yaml   |none  |     0|acc     |0.6434|±  |0.0291|
# |  - virology                           |Yaml   |none  |     0|acc     |0.4699|±  |0.0389|
# | - social_sciences                     |N/A    |none  |     0|acc     |0.6789|±  |0.0956|
# |  - econometrics                       |Yaml   |none  |     0|acc     |0.4035|±  |0.0462|
# |  - high_school_geography              |Yaml   |none  |     0|acc     |0.7626|±  |0.0303|
# |  - high_school_government_and_politics|Yaml   |none  |     0|acc     |0.8342|±  |0.0268|
# |  - high_school_macroeconomics         |Yaml   |none  |     0|acc     |0.5718|±  |0.0251|
# |  - high_school_microeconomics         |Yaml   |none  |     0|acc     |0.6092|±  |0.0317|
# |  - high_school_psychology             |Yaml   |none  |     0|acc     |0.7853|±  |0.0176|
# |  - human_sexuality                    |Yaml   |none  |     0|acc     |0.6947|±  |0.0404|
# |  - professional_psychology            |Yaml   |none  |     0|acc     |0.5703|±  |0.0200|
# |  - public_relations                   |Yaml   |none  |     0|acc     |0.6818|±  |0.0446|
# |  - security_studies                   |Yaml   |none  |     0|acc     |0.6898|±  |0.0296|
# |  - sociology                          |Yaml   |none  |     0|acc     |0.8408|±  |0.0259|
# |  - us_foreign_policy                  |Yaml   |none  |     0|acc     |0.8200|±  |0.0386|
# | - stem                                |N/A    |none  |     0|acc     |0.4767|±  |0.1140|
# |  - abstract_algebra                   |Yaml   |none  |     0|acc     |0.2900|±  |0.0456|
# |  - anatomy                            |Yaml   |none  |     0|acc     |0.5704|±  |0.0428|
# |  - astronomy                          |Yaml   |none  |     0|acc     |0.6118|±  |0.0397|
# |  - college_biology                    |Yaml   |none  |     0|acc     |0.6250|±  |0.0405|
# |  - college_chemistry                  |Yaml   |none  |     0|acc     |0.3800|±  |0.0488|
# |  - college_computer_science           |Yaml   |none  |     0|acc     |0.5400|±  |0.0501|
# |  - college_mathematics                |Yaml   |none  |     0|acc     |0.3700|±  |0.0485|
# |  - college_physics                    |Yaml   |none  |     0|acc     |0.3627|±  |0.0478|
# |  - computer_security                  |Yaml   |none  |     0|acc     |0.7100|±  |0.0456|
# |  - conceptual_physics                 |Yaml   |none  |     0|acc     |0.4553|±  |0.0326|
# |  - electrical_engineering             |Yaml   |none  |     0|acc     |0.5172|±  |0.0416|
# |  - elementary_mathematics             |Yaml   |none  |     0|acc     |0.3677|±  |0.0248|
# |  - high_school_biology                |Yaml   |none  |     0|acc     |0.6871|±  |0.0264|
# |  - high_school_chemistry              |Yaml   |none  |     0|acc     |0.4778|±  |0.0351|
# |  - high_school_computer_science       |Yaml   |none  |     0|acc     |0.5800|±  |0.0496|
# |  - high_school_mathematics            |Yaml   |none  |     0|acc     |0.3370|±  |0.0288|
# |  - high_school_physics                |Yaml   |none  |     0|acc     |0.3113|±  |0.0378|
# |  - high_school_statistics             |Yaml   |none  |     0|acc     |0.4398|±  |0.0339|
# |  - machine_learning                   |Yaml   |none  |     0|acc     |0.4911|±  |0.0475|
# |openbookqa                             |Yaml   |none  |     0|acc     |0.3200|±  |0.0209|
# |                                       |       |none  |     0|acc_norm|0.4320|±  |0.0222|
# |piqa                                   |Yaml   |none  |     0|acc     |0.8079|±  |0.0092|
# |                                       |       |none  |     0|acc_norm|0.8221|±  |0.0089|
# |winogrande                             |Yaml   |none  |     0|acc     |0.7238|±  |0.0126|
#
# |      Groups      |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------------------|-------|------|-----:|------|-----:|---|-----:|
# |mmlu              |N/A    |none  |     0|acc   |0.5743|±  |0.1427|
# | - humanities     |N/A    |none  |     0|acc   |0.5158|±  |0.1640|
# | - other          |N/A    |none  |     0|acc   |0.6585|±  |0.1141|
# | - social_sciences|N/A    |none  |     0|acc   |0.6789|±  |0.0956|
# | - stem           |N/A    |none  |     0|acc   |0.4767|±  |0.1140|
