# %% [markdown]
# ## Introduction

# %%
# Import Modules
from datasets import load_dataset
from huggingface_hub import notebook_login
from transformers import DataCollatorForLanguageModeling, Trainer, TrainingArguments, AutoTokenizer, AutoModelForCausalLM
from unsloth import FastLanguageModel, save

# %%
# Set Name Constants
model_name = 'mistralai/Mistral-7B-Instruct-v0.2'
hf_model_name = 'Mistral-Instruct-7B-v0.2-ChatAlpacaV2'

# %%
# HuggingFace Hub Login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Create Mistral model with Unsloth

# %%
# Constants
MAX_LEN = 8192

# Load model
model, tokenizer = FastLanguageModel.from_pretrained(model_name = model_name,
                                                     max_seq_length = MAX_LEN,
                                                     dtype = None, 
                                                     load_in_4bit = True)

# Do model patching and add fast LoRA weights
model = FastLanguageModel.get_peft_model(model,
                                         r = 32,
                                         target_modules = ['k_proj', 'o_proj', 'q_proj', 'v_proj'],
                                         lora_alpha = 16,
                                         lora_dropout = 0,
                                         bias = "none",
                                         use_gradient_checkpointing = True,
                                         random_state = 42)

# Set cache to False
model.config.use_cache = False

# Show Model Summary
print(model)
# Out:
# Unsloth: You passed in `mistralai/Mistral-7B-Instruct-v0.2` and `load_in_4bit = True`.
# We shall load `unsloth/mistral-7b-instruct-v0.2-bnb-4bit` for 4x faster loading.
# ==((====))==  Unsloth: Fast Mistral patching release 2024.1
#    \\   /|    GPU: NVIDIA GeForce RTX 4060 Ti. Max memory: 15.706 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.1.1+cu121. CUDA = 8.9. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.23. FA = True.
#  "-____-"     Apache 2 free license: http://github.com/unslothai/unsloth
# You passed `quantization_config` to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` attribute will be overwritten with the one you passed to `from_pretrained`.
# Unsloth cannot patch MLP layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Unsloth 2024.1 patched 32 layers with 32 QKV layers, 32 O layers and 0 MLP layers.
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralSdpaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Dataset and Tokenization

# %%
# Set Padding
tokenizer.pad_token = tokenizer.unk_token
model.config.pad_token_id = tokenizer.unk_token_id

# Tokenizer Summary
print(tokenizer)
# Out:
# LlamaTokenizerFast(name_or_path='unsloth/mistral-7b-instruct-v0.2-bnb-4bit', vocab_size=32000, model_max_length=32768, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
# Load ChatAlpaca
datasets = load_dataset('robinsmits/ChatAlpaca-20K')

# Train and Val datasets
train_data = datasets['train']
test_data = datasets['test']

# Summary
print(train_data)
print(test_data)
# Out:
# Dataset({
#     features: ['id', 'messages'],
#     num_rows: 19600
# })
# Dataset({
#     features: ['id', 'messages'],
#     num_rows: 400
# })

# %% [markdown]
# ## Show Chat Template Examples

# %%
# Show some samples
counter = 0
for item_data in train_data:
    print('\n=======================================================================')
    chat_template_string = tokenizer.apply_chat_template(item_data["messages"], tokenize = False)
    print(chat_template_string)

    counter += 1
    if counter == 2:
        break
# Out:
# =======================================================================
# <s>[INST] Find the product of the numbers: 5 and 8 [/INST]The product of 5 and 8 is 40.</s>[INST] What is the sum of the numbers 6 and 12? [/INST]The sum of the numbers 6 and 12 is 18.</s>[INST] Can you tell me the quotient of 20 and 5? [/INST]Yes, the quotient of 20 and 5 is 4.</s>[INST] What is the difference between 25 and 13? [/INST]The difference between 25 and 13 is 12.</s>[INST] What is the square of 9? [/INST]The square of 9 is 81.</s>[INST] What is the cube of 6? [/INST]The cube of 6 is 216.</s>
#
# =======================================================================
# <s>[INST] Provide five tips for effectively using tape measures [/INST]1. Tighten the tape measure so that it stays in place when measuring.
# 2. Make sure that the hook of the tape measure hits the starting point precisely.
# 3. Allow for a bit of slack when measuring around curves or corners.
# 4. Measure from a stable surface, such as a table or workbench.
# 5. Mark the beginning and end of each measurement with a pen or marker.</s>[INST] Can you give me an example of when to use tip number three, "Allow for a bit of slack when measuring around curves or corners"? [/INST]Sure! Let's say you're measuring the circumference of a circular object, like a pipe. If you pull the tape measure too tightly, you won't get an accurate measurement because the tape measure will be stretched out of its original shape, making the measurement longer than it should be. Instead, you should wrap the tape measure around the curve or corner of the object without pulling it too tightly. This way, you'll get a more accurate measurement that takes into account the shape of the object.</s>[INST] Can you tell me more about the markers or pens that should be used to mark the measurements? Do you recommend a certain type of pen? [/INST]As an AI language model, I do not have personal preferences as a human, but there are certain types of markers or pens that are better suited for marking measurements than others. For example, a fine-tipped marker or mechanical pencil is great for making precise marks on a tape measure, because they produce a precise line that is easy to see. You'll want to avoid using a ballpoint pen or a marker with a thick tip, since these types of pens can produce marks that are too thick or blurry, making it difficult to accurately read the measurement. It's also a good idea to choose a marker or pen that is a different color than the color of the tape measure, so that you can easily distinguish your marks from the printed markings on the tape measure.</s>[INST] Are there any other tips you recommend for maintaining tape measures in good condition?  [/INST]Yes, there are several tips you can use to maintain your tape measures in good condition:
#
# 1. Clean your tape measure regularly: Use a soft cloth or a damp sponge to clean the surface of the tape measure. Avoid using harsh chemicals or abrasives that could damage the markings on the tape measure.
#
# 2. Store your tape measure properly: Keep your tape measure in a dry place, away from moisture and direct sunlight. Avoid storing your tape measure in a place where it could get crushed or bent, as this could damage the internal components.
#
# 3. Wind the tape measure properly: When you're done using your tape measure, wind the tape back into the housing carefully to avoid twisting or kinking the tape. Make sure the hook is fully retracted and secure the lock.
#
# 4. Lubricate the mechanism: Use a light lubricant like silicone spray to keep the internal components of the tape measure moving smoothly. Be careful not to over-lubricate, as this could cause the tape measure to become greasy and difficult to handle.
#
# By following these tips, you can help to ensure that your tape measures are always in good working condition, and that you'll be able to rely on them for accurate measurements every time you use them.</s>

# %% [markdown]
# ## Tokenize Datasets

# %%
train_data = train_data.shuffle().map(lambda x: {"input_ids": tokenizer.apply_chat_template(x['messages'], 
                                                                                            tokenize = True, 
                                                                                            max_length = MAX_LEN,
                                                                                            truncation = True,
                                                                                            add_generation_prompt = False)})

test_data = test_data.map(lambda x: {"input_ids": tokenizer.apply_chat_template(x['messages'], 
                                                                                tokenize = True,
                                                                                max_length = MAX_LEN,
                                                                                truncation = True,
                                                                                add_generation_prompt = False)})

# %% [markdown]
# ## Train Model

# %%
# Set Steps
eval_steps = 120
save_steps = 300
logging_steps = 30

# Config Trainer
trainer = Trainer(model = model,
                  train_dataset = train_data,
                  eval_dataset = test_data,
                  args = TrainingArguments(num_train_epochs = 1,
                                           learning_rate = 5.0e-5,
                                           lr_scheduler_type = 'cosine',
                                           evaluation_strategy = "steps",
                                           logging_steps = logging_steps,
                                           save_strategy = 'steps',
                                           eval_steps = eval_steps,
                                           save_steps = save_steps,
                                           save_total_limit = 1,
                                           per_device_train_batch_size = 2,
                                           per_device_eval_batch_size = 4,
                                           gradient_accumulation_steps = 16,
                                           gradient_checkpointing = True, 
                                           gradient_checkpointing_kwargs = {'use_reentrant': False},
                                           warmup_ratio = 0.05,
                                           bf16 = True,
                                           output_dir = hf_model_name,
                                           hub_model_id = hf_model_name,
                                           push_to_hub = True,
                                           hub_private_repo = False,
                                           optim = 'paged_adamw_8bit',
                                           weight_decay = 0.0001,
                                           report_to = 'tensorboard'),
                  data_collator = DataCollatorForLanguageModeling(tokenizer, mlm = False))

# Perform Training
trainer.train()
# Out:
#   0%|          | 0/612 [00:00<?, ?it/s]
# {'loss': 1.6823, 'learning_rate': 4.8387096774193554e-05, 'epoch': 0.05}
# {'loss': 0.988, 'learning_rate': 4.969326495615839e-05, 'epoch': 0.1}
# {'loss': 0.916, 'learning_rate': 4.873853577196727e-05, 'epoch': 0.15}
# {'loss': 0.8801, 'learning_rate': 4.716051485520689e-05, 'epoch': 0.2}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'eval_loss': 0.8755983710289001, 'eval_runtime': 175.5935, 'eval_samples_per_second': 2.278, 'eval_steps_per_second': 0.569, 'epoch': 0.2}
# {'loss': 0.8826, 'learning_rate': 4.500063556978337e-05, 'epoch': 0.24}
# {'loss': 0.877, 'learning_rate': 4.2315608865137044e-05, 'epoch': 0.29}
# {'loss': 0.8628, 'learning_rate': 3.917593424312474e-05, 'epoch': 0.34}
# {'loss': 0.8498, 'learning_rate': 3.5664048685271176e-05, 'epoch': 0.39}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'eval_loss': 0.8552566766738892, 'eval_runtime': 176.3184, 'eval_samples_per_second': 2.269, 'eval_steps_per_second': 0.567, 'epoch': 0.39}
# {'loss': 0.8643, 'learning_rate': 3.187216214314904e-05, 'epoch': 0.44}
# {'loss': 0.8484, 'learning_rate': 2.789983642441356e-05, 'epoch': 0.49}
# {'loss': 0.8516, 'learning_rate': 2.3851371044559023e-05, 'epoch': 0.54}
# {'loss': 0.8515, 'learning_rate': 1.9833064682876176e-05, 'epoch': 0.59}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'eval_loss': 0.8475459814071655, 'eval_runtime': 175.5917, 'eval_samples_per_second': 2.278, 'eval_steps_per_second': 0.57, 'epoch': 0.59}
# {'loss': 0.8522, 'learning_rate': 1.5950424147292275e-05, 'epoch': 0.64}
# {'loss': 0.8464, 'learning_rate': 1.2305394131010587e-05, 'epoch': 0.69}
# {'loss': 0.8603, 'learning_rate': 8.993680497945334e-06, 'epoch': 0.73}
# {'loss': 0.8313, 'learning_rate': 6.1022373782061e-06, 'epoch': 0.78}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'eval_loss': 0.8444544076919556, 'eval_runtime': 175.6006, 'eval_samples_per_second': 2.278, 'eval_steps_per_second': 0.569, 'epoch': 0.78}
# {'loss': 0.8554, 'learning_rate': 3.7069840538008327e-06, 'epoch': 0.83}
# {'loss': 0.8527, 'learning_rate': 1.870811581231585e-06, 'epoch': 0.88}
# {'loss': 0.8412, 'learning_rate': 6.419314901696671e-07, 'epoch': 0.93}
# {'loss': 0.857, 'learning_rate': 5.260991566382878e-08, 'epoch': 0.98}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'eval_loss': 0.8438799977302551, 'eval_runtime': 176.3243, 'eval_samples_per_second': 2.269, 'eval_steps_per_second': 0.567, 'epoch': 0.98}
# {'train_runtime': 24991.2299, 'train_samples_per_second': 0.784, 'train_steps_per_second': 0.024, 'train_loss': 0.9065010734632903, 'epoch': 1.0}
# TrainOutput(global_step=612, training_loss=0.9065010734632903, metrics={'train_runtime': 24991.2299, 'train_samples_per_second': 0.784, 'train_steps_per_second': 0.024, 'train_loss': 0.9065010734632903, 'epoch': 1.0})

# %% [markdown]
# ## Push to Hub

# %%
# Push model to hub
trainer.push_to_hub()

# Push tokenizer to hub
tokenizer.push_to_hub(hf_model_name, private = False)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# events.out.tfevents.1707661759.DS10.684074.0:   0%|          | 0.00/9.76k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/robinsmits/Mistral-Instruct-7B-v0.2-ChatAlpacaV2/commit/5bdbbca91a8bed89d10f498dc9ff77bbdadedf3a', commit_message='Upload tokenizer', commit_description='', oid='5bdbbca91a8bed89d10f498dc9ff77bbdadedf3a', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Merge and Push to Hub 4bit version

# %%
# Merge, Save and Push - 4 Bits
save.unsloth_save_model(model, tokenizer, save_directory = f'./{hf_model_name}-4bit', save_method = "merged_4bit_forced")

# Push Model
model_4bit = AutoModelForCausalLM.from_pretrained(f'./{hf_model_name}-4bit', load_in_4bit = True)
model_4bit.push_to_hub(f'{hf_model_name}-4bit', private = False)

# Push Tokenizer
tokenizer_4bit = AutoTokenizer.from_pretrained(f'./{hf_model_name}-4bit')
tokenizer_4bit.push_to_hub(f'{hf_model_name}-4bit', private = False)
# Out:
# Unsloth: Merging 4bit and LoRA weights to 4bit...
# This might take 5 minutes...
# /home/robin/environments/TORCH211/lib/python3.10/site-packages/peft/tuners/lora/bnb.py:249: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# Done.
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 10 minutes for Llama-7b...
# You passed `quantization_config` to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` attribute will be overwritten with the one you passed to `from_pretrained`.
#  Done.
# model.safetensors:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/robinsmits/Mistral-Instruct-7B-v0.2-ChatAlpacaV2-4bit/commit/baa4aa4d610e2e6c16619007c5466feac80b27a6', commit_message='Upload tokenizer', commit_description='', oid='baa4aa4d610e2e6c16619007c5466feac80b27a6', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Finetuned Model Evaluation

# %%
# !lm_eval --model hf \
         --model_args pretrained=unsloth/mistral-7b-instruct-v0.2-bnb-4bit,peft=robinsmits/Mistral-Instruct-7B-v0.2-ChatAlpacaV2 \
         --tasks arc_challenge,arc_easy,hellaswag,mmlu,truthfulqa,winogrande,gsm8k \
         --device cuda \
         --batch_size 2 \
         --verbosity ERROR
# Out:
# 2024-02-13:13:57:29,876 INFO     [utils.py:148] Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-02-13:13:57:29,876 INFO     [utils.py:160] NumExpr defaulting to 8 threads.
# 2024-02-13:13:57:29,989 INFO     [config.py:58] PyTorch version 2.1.1 available.
# /home/robin/environments/TORCH211/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /home/robin/environments/TORCH211/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 100%|█████████████████████████████████| 123054/123054 [4:56:58<00:00,  6.91it/s]
#   0%|                                                  | 0/2136 [00:00<?, ?it/s]/home/robin/environments/TORCH211/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:392: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|█████████████████████████████████████| 2136/2136 [9:33:09<00:00, 16.10s/it]
# 2024-02-14:04:31:55,163 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,198 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,233 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,268 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,303 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,339 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,375 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,410 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,445 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,480 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,515 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,550 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,585 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,622 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,657 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,692 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,727 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,762 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,797 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,833 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,867 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,902 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,937 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:55,972 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,006 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,042 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,076 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,111 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,146 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,182 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,219 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,257 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,293 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,329 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,365 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,400 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,436 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,471 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,507 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,543 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,579 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,615 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,652 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,687 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,722 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,757 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,792 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,828 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,864 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,899 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,934 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:56,969 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,004 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,039 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,075 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,110 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,146 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,182 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,218 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,254 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,289 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,326 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,363 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,401 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,437 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,474 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,510 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,546 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,583 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,620 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,657 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,693 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,730 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,767 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,803 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,838 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,876 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,912 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,947 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:57,984 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,019 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,056 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,092 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,129 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,165 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,204 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,244 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,282 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,319 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,355 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,391 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,428 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,464 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,503 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,541 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,577 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,613 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,651 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,688 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,724 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,759 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,794 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,829 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,865 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,900 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,936 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:58,971 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,008 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,043 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,078 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,114 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,150 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,186 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,222 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,260 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,297 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,333 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,368 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,404 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,439 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,475 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,510 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,545 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,580 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,618 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,654 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,688 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,723 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,761 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,795 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,830 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,865 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,902 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,937 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:31:59,973 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,008 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,046 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,083 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,120 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,156 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,192 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,233 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,273 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,308 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,343 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,379 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,414 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,450 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,484 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32:00,521 INFO     [rouge_scorer.py:83] Using default tokenizer.
# 2024-02-14:04:32
# |---------------------------------------|-------|----------|-----:|-----------|------:|---|-----:|
# |arc_challenge                          |Yaml   |none      |     0|acc        | 0.5213|±  |0.0146|
# |                                       |       |none      |     0|acc_norm   | 0.5435|±  |0.0146|
# |arc_easy                               |Yaml   |none      |     0|acc        | 0.8119|±  |0.0080|
# |                                       |       |none      |     0|acc_norm   | 0.7900|±  |0.0084|
# |gsm8k                                  |Yaml   |get-answer|     5|exact_match| 0.3723|±  |0.0133|
# |hellaswag                              |Yaml   |none      |     0|acc        | 0.6050|±  |0.0049|
# |                                       |       |none      |     0|acc_norm   | 0.7917|±  |0.0041|
# |mmlu                                   |N/A    |none      |     0|acc        | 0.5695|±  |0.1412|
# | - humanities                          |N/A    |none      |     0|acc        | 0.5167|±  |0.1627|
# |  - formal_logic                       |Yaml   |none      |     0|acc        | 0.3413|±  |0.0424|
# |  - high_school_european_history       |Yaml   |none      |     0|acc        | 0.7030|±  |0.0357|
# |  - high_school_us_history             |Yaml   |none      |     0|acc        | 0.7647|±  |0.0298|
# |  - high_school_world_history          |Yaml   |none      |     0|acc        | 0.7595|±  |0.0278|
# |  - international_law                  |Yaml   |none      |     0|acc        | 0.7438|±  |0.0398|
# |  - jurisprudence                      |Yaml   |none      |     0|acc        | 0.7222|±  |0.0433|
# |  - logical_fallacies                  |Yaml   |none      |     0|acc        | 0.7362|±  |0.0346|
# |  - moral_disputes                     |Yaml   |none      |     0|acc        | 0.6647|±  |0.0254|
# |  - moral_scenarios                    |Yaml   |none      |     0|acc        | 0.2391|±  |0.0143|
# |  - philosophy                         |Yaml   |none      |     0|acc        | 0.6367|±  |0.0273|
# |  - prehistory                         |Yaml   |none      |     0|acc        | 0.6481|±  |0.0266|
# |  - professional_law                   |Yaml   |none      |     0|acc        | 0.4329|±  |0.0127|
# |  - world_religions                    |Yaml   |none      |     0|acc        | 0.7719|±  |0.0322|
# | - other                               |N/A    |none      |     0|acc        | 0.6440|±  |0.1201|
# |  - business_ethics                    |Yaml   |none      |     0|acc        | 0.5700|±  |0.0498|
# |  - clinical_knowledge                 |Yaml   |none      |     0|acc        | 0.6453|±  |0.0294|
# |  - college_medicine                   |Yaml   |none      |     0|acc        | 0.5376|±  |0.0380|
# |  - global_facts                       |Yaml   |none      |     0|acc        | 0.3300|±  |0.0473|
# |  - human_aging                        |Yaml   |none      |     0|acc        | 0.6457|±  |0.0321|
# |  - management                         |Yaml   |none      |     0|acc        | 0.7087|±  |0.0450|
# |  - marketing                          |Yaml   |none      |     0|acc        | 0.8675|±  |0.0222|
# |  - medical_genetics                   |Yaml   |none      |     0|acc        | 0.6000|±  |0.0492|
# |  - miscellaneous                      |Yaml   |none      |     0|acc        | 0.7791|±  |0.0148|
# |  - nutrition                          |Yaml   |none      |     0|acc        | 0.6438|±  |0.0274|
# |  - professional_accounting            |Yaml   |none      |     0|acc        | 0.4149|±  |0.0294|
# |  - professional_medicine              |Yaml   |none      |     0|acc        | 0.6103|±  |0.0296|
# |  - virology                           |Yaml   |none      |     0|acc        | 0.4639|±  |0.0388|
# | - social_sciences                     |N/A    |none      |     0|acc        | 0.6682|±  |0.0955|
# |  - econometrics                       |Yaml   |none      |     0|acc        | 0.3947|±  |0.0460|
# |  - high_school_geography              |Yaml   |none      |     0|acc        | 0.7424|±  |0.0312|
# |  - high_school_government_and_politics|Yaml   |none      |     0|acc        | 0.8187|±  |0.0278|
# |  - high_school_macroeconomics         |Yaml   |none      |     0|acc        | 0.5436|±  |0.0253|
# |  - high_school_microeconomics         |Yaml   |none      |     0|acc        | 0.5882|±  |0.0320|
# |  - high_school_psychology             |Yaml   |none      |     0|acc        | 0.7688|±  |0.0181|
# |  - human_sexuality                    |Yaml   |none      |     0|acc        | 0.7252|±  |0.0392|
# |  - professional_psychology            |Yaml   |none      |     0|acc        | 0.5784|±  |0.0200|
# |  - public_relations                   |Yaml   |none      |     0|acc        | 0.6182|±  |0.0465|
# |  - security_studies                   |Yaml   |none      |     0|acc        | 0.6939|±  |0.0295|
# |  - sociology                          |Yaml   |none      |     0|acc        | 0.8308|±  |0.0265|
# |  - us_foreign_policy                  |Yaml   |none      |     0|acc        | 0.8100|±  |0.0394|
# | - stem                                |N/A    |none      |     0|acc        | 0.4786|±  |0.1123|
# |  - abstract_algebra                   |Yaml   |none      |     0|acc        | 0.2700|±  |0.0446|
# |  - anatomy                            |Yaml   |none      |     0|acc        | 0.5481|±  |0.0430|
# |  - astronomy                          |Yaml   |none      |     0|acc        | 0.5987|±  |0.0399|
# |  - college_biology                    |Yaml   |none      |     0|acc        | 0.6111|±  |0.0408|
# |  - college_chemistry                  |Yaml   |none      |     0|acc        | 0.3700|±  |0.0485|
# |  - college_computer_science           |Yaml   |none      |     0|acc        | 0.5200|±  |0.0502|
# |  - college_mathematics                |Yaml   |none      |     0|acc        | 0.3700|±  |0.0485|
# |  - college_physics                    |Yaml   |none      |     0|acc        | 0.3627|±  |0.0478|
# |  - computer_security                  |Yaml   |none      |     0|acc        | 0.7100|±  |0.0456|
# |  - conceptual_physics                 |Yaml   |none      |     0|acc        | 0.4638|±  |0.0326|
# |  - electrical_engineering             |Yaml   |none      |     0|acc        | 0.5517|±  |0.0414|
# |  - elementary_mathematics             |Yaml   |none      |     0|acc        | 0.3968|±  |0.0252|
# |  - high_school_biology                |Yaml   |none      |     0|acc        | 0.6774|±  |0.0266|
# |  - high_school_chemistry              |Yaml   |none      |     0|acc        | 0.4975|±  |0.0352|
# |  - high_school_computer_science       |Yaml   |none      |     0|acc        | 0.6300|±  |0.0485|
# |  - high_school_mathematics            |Yaml   |none      |     0|acc        | 0.3222|±  |0.0285|
# |  - high_school_physics                |Yaml   |none      |     0|acc        | 0.3377|±  |0.0386|
# |  - high_school_statistics             |Yaml   |none      |     0|acc        | 0.4259|±  |0.0337|
# |  - machine_learning                   |Yaml   |none      |     0|acc        | 0.4643|±  |0.0473|
# |truthfulqa                             |N/A    |none      |     0|acc        | 0.4193|±  |0.0540|
# |                                       |       |none      |     0|bleu_max   |32.8497|±  |0.7607|
# |                                       |       |none      |     0|bleu_acc   | 0.5324|±  |0.0003|
# |                                       |       |none      |     0|bleu_diff  | 7.6395|±  |1.0051|
# |                                       |       |none      |     0|rouge1_max |59.0318|±  |0.8492|
# |                                       |       |none      |     0|rouge1_acc | 0.5324|±  |0.0003|
# |                                       |       |none      |     0|rouge1_diff| 9.9661|±  |1.7722|
# |                                       |       |none      |     0|rouge2_max |45.1667|±  |1.2160|
# |                                       |       |none      |     0|rouge2_acc | 0.4798|±  |0.0003|
# |                                       |       |none      |     0|rouge2_diff|10.2034|±  |2.0543|
# |                                       |       |none      |     0|rougeL_max |56.0785|±  |0.9069|
# |                                       |       |none      |     0|rougeL_acc | 0.5226|±  |0.0003|
# |                                       |       |none      |     0|rougeL_diff| 9.4445|±  |1.8088|
# | - truthfulqa_gen                      |Yaml   |none      |     0|bleu_max   |32.8497|±  |0.8722|
# |                                       |       |none      |     0|bleu_acc   | 0.5324|±  |0.0175|
# |                                       |       |none      |     0|bleu_diff  | 7.6395|±  |1.0026|
# |                                       |       |none      |     0|rouge1_max |59.0318|±  |0.9215|
# |                                       |       |none      |     0|rouge1_acc | 0.5324|±  |0.0175|
# |                                       |       |none      |     0|rouge1_diff| 9.9661|±  |1.3312|
# |                                       |       |none      |     0|rouge2_max |45.1667|±  |1.1027|
# |                                       |       |none      |     0|rouge2_acc | 0.4798|±  |0.0175|
# |                                       |       |none      |     0|rouge2_diff|10.2034|±  |1.4333|
# |                                       |       |none      |     0|rougeL_max |56.0785|±  |0.9523|
# |                                       |       |none      |     0|rougeL_acc | 0.5226|±  |0.0175|
# |                                       |       |none      |     0|rougeL_diff| 9.4445|±  |1.3449|
# | - truthfulqa_mc1                      |Yaml   |none      |     0|acc        | 0.3647|±  |0.0169|
# | - truthfulqa_mc2                      |Yaml   |none      |     0|acc        | 0.5285|±  |0.0152|
# |winogrande                             |Yaml   |none      |     0|acc        | 0.7198|±  |0.0126|
#
# |      Groups      |Version|Filter|n-shot|  Metric   | Value |   |Stderr|
# |------------------|-------|------|-----:|-----------|------:|---|-----:|
# |mmlu              |N/A    |none  |     0|acc        | 0.5695|±  |0.1412|
# | - humanities     |N/A    |none  |     0|acc        | 0.5167|±  |0.1627|
# | - other          |N/A    |none  |     0|acc        | 0.6440|±  |0.1201|
# | - social_sciences|N/A    |none  |     0|acc        | 0.6682|±  |0.0955|
# | - stem           |N/A    |none  |     0|acc        | 0.4786|±  |0.1123|
# |truthfulqa        |N/A    |none  |     0|acc        | 0.4193|±  |0.0540|
# |                  |       |none  |     0|bleu_max   |32.8497|±  |0.7607|
# |                  |       |none  |     0|bleu_acc   | 0.5324|±  |0.0003|
# |                  |       |none  |     0|bleu_diff  | 7.6395|±  |1.0051|
# |                  |       |none  |     0|rouge1_max |59.0318|±  |0.8492|
# |                  |       |none  |     0|rouge1_acc | 0.5324|±  |0.0003|
# |                  |       |none  |     0|rouge1_diff| 9.9661|±  |1.7722|
# |                  |       |none  |     0|rouge2_max |45.1667|±  |1.2160|
# |                  |       |none  |     0|rouge2_acc | 0.4798|±  |0.0003|
# |                  |       |none  |     0|rouge2_diff|10.2034|±  |2.0543|
# |                  |       |none  |     0|rougeL_max |56.0785|±  |0.9069|
# |                  |       |none  |     0|rougeL_acc | 0.5226|±  |0.0003|
# |                  |       |none  |     0|rougeL_diff| 9.4445|±  |1.8088|
